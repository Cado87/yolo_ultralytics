# %% [markdown]
# <a href="https://colab.research.google.com/github/Cado87/yolo_ultralytics/blob/main/conversion_pt_model_to_tflite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("yolo11n.pt")

# Export the model to TFLite format
model.export(format="tflite")  # creates 'yolo11n_float32.tflite'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0,<1.4.0', 'onnx>=1.12.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.65', 'onnxruntime'] not found, attempting AutoUpdate...
#
# ...

# %%
# Load the exported TFLite model
tflite_model = YOLO("/content/yolo11n_saved_model/yolo11n_float32.tflite")

# Run inference
results = tflite_model("https://ultralytics.com/images/bus.jpg")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /content/yolo11n_saved_model/yolo11n_float32.tflite for TensorFlow Lite inference...
#
# ...
# image 1/1 /content/bus.jpg: 640x640 4 persons, 1 bus, 150.7ms
# Speed: 16.1ms preprocess, 150.7ms inference, 32.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Load the exported TFLite model
tflite_model = YOLO("/content/yolo11n_saved_model/yolo11n_float16.tflite")

# Run inference
results = tflite_model("https://ultralytics.com/images/bus.jpg")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /content/yolo11n_saved_model/yolo11n_float16.tflite for TensorFlow Lite inference...
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x640 4 persons, 1 bus, 158.0ms
# Speed: 3.6ms preprocess, 158.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
